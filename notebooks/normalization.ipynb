# %%
import numpy as np
import pandas as pd
import sklearn.preprocessing as skp
import sklearn.model_selection as skm

# %%
df = pd.read_parquet('./data/btcusd_15min.pkl')

# %%
df = pd.read_parquet('/Users/Codes/Bitcoin_trader/data/btcusd_15min_preprcd.parquet')

# %%
df.head()
# Out:
#        Timestamp  open  close  high   low  Volume  MACD_Histogram    SMA  \
# 41  1.325449e+09  4.58   4.84  4.84  4.58    10.0        0.016593  4.593
# 42  1.325450e+09  4.84   4.84  4.84  4.84     0.0        0.026085  4.606
# 43  1.325451e+09  4.84   4.84  4.84  4.84     0.0        0.030570  4.619
# 44  1.325452e+09  4.84   4.84  4.84  4.84     0.0        0.031611  4.632
# 45  1.325453e+09  4.84   4.84  4.84  4.84     0.0        0.030368  4.645
#
#        BB_up   BB_down  ...   OBV         CCI       pmo        R1        R2  \
# 41  4.709276  4.476724  ...  10.0  231.626410  5.676856  4.926667  5.013333
# 42  4.766053  4.445947  ...  10.0  157.359158  5.676856  4.840000  4.840000
# 43  4.809501  4.428499  ...  10.0  123.013313  5.676856  4.840000  4.840000
# 44  4.845403  4.418597  ...  10.0  101.574900  5.676856  4.840000  4.840000
# 45  4.876016  4.413984  ...  10.0   86.189161  5.676856  4.840000  4.840000
#
#           R3        S1        S2        S3  future_price
# ...
